# %% [markdown]
# ## Part 1

# %%
import pandas as pd
from collections import Counter

inputs = open('input.txt','r')

def up(row):
    row +=1
    return row

def down(row):
    row -=1
    return row
    
def left(col):
    col -=1
    return col
    
def right(col):
    col +=1
    return col

h_col = 0
h_row = 0
h_positions = [[0,0]]
t_positions = [[0,0]]
t_col = 0
t_row = 0


for input in inputs:
    new = input.replace('\n','')
    movement = new.split(' ')
    direction = movement[0]
    steps = int(movement[1])
    for i in range(0, steps, 1):
        if direction == 'U':
            h_row = up(h_row)
            h_positions.append([h_col,h_row])
        elif direction == 'D':
            h_row = down(h_row)
            h_positions.append([h_col,h_row])
        elif direction == 'L':
            h_col = left(h_col)
            h_positions.append([h_col,h_row])
        else:
            h_col = right(h_col)
            h_positions.append([h_col,h_row])
        h_position = [h_col,h_row]
        
        if h_position in [[t_col+1,t_row],[t_col-1,t_row],[t_col,t_row+1], #if head is around tail or in the same spot as tail
                              [t_col, t_row-1],[t_col+1, t_row+1],[t_col+1,t_row-1],
                              [t_col-1, t_row+1],[t_col-1, t_row-1],[t_col,t_row]]:
            t_positions.append([t_col, t_row]) #tail doesn't move
        elif (h_col == t_col) and (h_row != t_row): #if head is in the same column but different row as tail
            if h_row > t_row: #head is 2 spots up from tail
                t_row = up(t_row)
                t_positions.append([t_col, t_row])
            else: #head is 2 spots down from tail
                t_row = down(t_row)
                t_positions.append([t_col, t_row])
        elif (h_col != t_col) and (h_row == t_row): #if head is in the same row but different col as tail
            if h_col > t_col: #head is 2 spots to the right from tail
                t_col = right(t_col)
                t_positions.append([t_col, t_row])
            else: #head is 2 spots to the left from tail
                t_col = left(t_col)
                t_positions.append([t_col, t_row])
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (h_col > t_col) and (h_row > t_row): #tail needs to move right & up
                t_row = up(t_row)
                t_col = right(t_col)
                t_positions.append([t_col, t_row])
            elif (h_col > t_col) and (h_row < t_row): #tail needs to move right & down
                t_row = down(t_row)
                t_col = right(t_col)
                t_positions.append([t_col, t_row])
            elif (h_col < t_col) and (h_row > t_row): #tail needs to move left & up
                t_row = up(t_row)
                t_col = left(t_col)
                t_positions.append([t_col, t_row])
            else: #tail needs to move left & down
                t_row = down(t_row)
                t_col = left(t_col)
                t_positions.append([t_col, t_row])
print(len(set(map(tuple,t_positions))))
# Out:
# 5858

# %% [markdown]
# ## Part 2

# %%
import pandas as pd
from collections import Counter

inputs = open('input.txt','r')

def up(row):
    row +=1
    return row

def down(row):
    row -=1
    return row
    
def left(col):
    col -=1
    return col
    
def right(col):
    col +=1
    return col

h_col = 0
h_row = 0
h_positions = [[0,0]]
one_positions = [[0,0]]
t_col = 0
t_row = 0


two_positions = [[0,0]]
two_row = 0
two_col = 0

three_positions = [[0,0]]
three_row = 0
three_col = 0

four_positions =[[0,0]]
four_row = 0 
four_col = 0

five_positions = [[0,0]]
five_row = 0
five_col = 0

six_positions = [[0,0]]
six_row = 0
six_col = 0

seven_positions = [[0,0]]
seven_row = 0
seven_col = 0

eight_positions = [[0,0]]
eight_row = 0
eight_col = 0

nine_positions = [[0,0]]
nine_row = 0
nine_col = 0

for input in inputs:
    new = input.replace('\n','')
    movement = new.split(' ')
    direction = movement[0]
    steps = int(movement[1])
    for i in range(0, steps, 1):
        if direction == 'U':
            h_row = up(h_row)
            h_positions.append([h_col,h_row])
        elif direction == 'D':
            h_row = down(h_row)
            h_positions.append([h_col,h_row])
        elif direction == 'L':
            h_col = left(h_col)
            h_positions.append([h_col,h_row])
        else:
            h_col = right(h_col)
            h_positions.append([h_col,h_row])
        h_position = [h_col,h_row]
        
        if h_position in [[t_col+1,t_row],[t_col-1,t_row],[t_col,t_row+1], #if head is around tail or in the same spot as tail
                              [t_col, t_row-1],[t_col+1, t_row+1],[t_col+1,t_row-1],
                              [t_col-1, t_row+1],[t_col-1, t_row-1],[t_col,t_row]]:
            t_col = t_col
            t_row = t_row
        elif (h_col == t_col) and (h_row != t_row): #if head is in the same column but different row as tail
            if h_row > t_row: #head is 2 spots up from tail
                t_row = up(t_row)
            else: #head is 2 spots down from tail
                t_row = down(t_row)
        elif (h_col != t_col) and (h_row == t_row): #if head is in the same row but different col as tail
            if h_col > t_col: #head is 2 spots to the right from tail
                t_col = right(t_col)
            else: #head is 2 spots to the left from tail
                t_col = left(t_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (h_col > t_col) and (h_row > t_row): #tail needs to move right & up
                t_row = up(t_row)
                t_col = right(t_col)
            elif (h_col > t_col) and (h_row < t_row): #tail needs to move right & down
                t_row = down(t_row)
                t_col = right(t_col)
            elif (h_col < t_col) and (h_row > t_row): #tail needs to move left & up
                t_row = up(t_row)
                t_col = left(t_col)
            else: #tail needs to move left & down
                t_row = down(t_row)
                t_col = left(t_col)
        one_positions.append([t_col, t_row])
        one_position = [t_col, t_row]
        

        if one_position in [[two_col+1,two_row],[two_col-1,two_row],[two_col,two_row+1], #if head is around tail or in the same spot as tail
                              [two_col, two_row-1],[two_col+1, two_row+1],[two_col+1,two_row-1],
                              [two_col-1, two_row+1],[two_col-1, two_row-1],[two_col,two_row]]:
            two_col = two_col
            two_row = two_row
        elif (t_col == two_col) and (t_row != two_row): #if head is in the same column but different row as tail
            if t_row > two_row: #head is 2 spots up from tail
                two_row = up(two_row)
            else: #head is 2 spots down from tail
                two_row = down(two_row)
        elif (t_col != two_col) and (t_row == two_row): #if head is in the same row but different col as tail
            if t_col > two_col: #head is 2 spots to the right from tail
                two_col = right(two_col)
            else: #head is 2 spots to the left from tail
                two_col = left(two_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (t_col > two_col) and (t_row > two_row): #tail needs to move right & up
                two_row = up(two_row)
                two_col = right(two_col)
            elif (t_col > two_col) and (t_row < two_row): #tail needs to move right & down
                two_row = down(two_row)
                two_col = right(two_col)
            elif (t_col < two_col) and (t_row > two_row): #tail needs to move left & up
                two_row = up(two_row)
                two_col = left(two_col)
            else: #tail needs to move left & down
                two_row = down(two_row)
                two_col = left(two_col)
        two_positions.append([two_col, two_row])
        two_position = [two_col, two_row]
            
        
        
        if two_position in [[three_col+1,three_row],[three_col-1,three_row],[three_col,three_row+1], #if head is around tail or in the same spot as tail
                              [three_col, three_row-1],[three_col+1, three_row+1],[three_col+1,three_row-1],
                              [three_col-1, three_row+1],[three_col-1, three_row-1],[three_col,three_row]]:
            three_col = three_col
            three_row = three_row
        elif (two_col == three_col) and (two_row != three_row): #if head is in the same column but different row as tail
            if two_row > three_row: #head is 2 spots up from tail
                three_row = up(three_row)
            else: #head is 2 spots down from tail
                three_row = down(three_row)
        elif (two_col != three_col) and (two_row == three_row): #if head is in the same row but different col as tail
            if two_col > three_col: #head is 2 spots to the right from tail
                three_col = right(three_col)
            else: #head is 2 spots to the left from tail
                three_col = left(three_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (two_col > three_col) and (two_row > three_row): #tail needs to move right & up
                three_row = up(three_row)
                three_col = right(three_col)
            elif (two_col > three_col) and (two_row < three_row): #tail needs to move right & down
                three_row = down(three_row)
                three_col = right(three_col)
            elif (two_col < three_col) and (two_row > three_row): #tail needs to move left & up
                three_row = up(three_row)
                three_col = left(three_col)
            else: #tail needs to move left & down
                three_row = down(three_row)
                three_col = left(three_col)
        three_positions.append([three_col, three_row])
        three_position = [three_col, three_row]
        
        
        if three_position in [[four_col+1,four_row],[four_col-1,four_row],[four_col,four_row+1], #if head is around tail or in the same spot as tail
                              [four_col, four_row-1],[four_col+1, four_row+1],[four_col+1,four_row-1],
                              [four_col-1, four_row+1],[four_col-1, four_row-1],[four_col,four_row]]:
            four_col = four_col
            four_row = four_row
        elif (three_col == four_col) and (three_row != four_row): #if head is in the same column but different row as tail
            if three_row > four_row: #head is 2 spots up from tail
                four_row = up(four_row)
            else: #head is 2 spots down from tail
                four_row = down(four_row)
        elif (three_col != four_col) and (three_row == four_row): #if head is in the same row but different col as tail
            if three_col > four_col: #head is 2 spots to the right from tail
                four_col = right(four_col)
            else: #head is 2 spots to the left from tail
                four_col = left(four_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (three_col > four_col) and (three_row > four_row): #tail needs to move right & up
                four_row = up(four_row)
                four_col = right(four_col)
            elif (three_col > four_col) and (three_row < four_row): #tail needs to move right & down
                four_row = down(four_row)
                four_col = right(four_col)
            elif (three_col < four_col) and (three_row > four_row): #tail needs to move left & up
                four_row = up(four_row)
                four_col = left(four_col)
            else: #tail needs to move left & down
                four_row = down(four_row)
                four_col = left(four_col)
        four_positions.append([four_col, four_row])
        four_position = [four_col, four_row]


        if four_position in [[five_col+1,five_row],[five_col-1,five_row],[five_col,five_row+1], #if head is around tail or in the same spot as tail
                              [five_col, five_row-1],[five_col+1, five_row+1],[five_col+1,five_row-1],
                              [five_col-1, five_row+1],[five_col-1, five_row-1],[five_col,five_row]]:
            five_col = five_col
            five_row = five_row
        elif (four_col == five_col) and (four_row != five_row): #if head is in the same column but different row as tail
            if four_row > five_row: #head is 2 spots up from tail
                five_row = up(five_row)
            else: #head is 2 spots down from tail
                five_row = down(five_row)
        elif (four_col != five_col) and (four_row == five_row): #if head is in the same row but different col as tail
            if four_col > five_col: #head is 2 spots to the right from tail
                five_col = right(five_col)
            else: #head is 2 spots to the left from tail
                five_col = left(five_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (four_col > five_col) and (four_row > five_row): #tail needs to move right & up
                five_row = up(five_row)
                five_col = right(five_col)
            elif (four_col > five_col) and (four_row < five_row): #tail needs to move right & down
                five_row = down(five_row)
                five_col = right(five_col)
            elif (four_col < five_col) and (four_row > five_row): #tail needs to move left & up
                five_row = up(five_row)
                five_col = left(five_col)
            else: #tail needs to move left & down
                five_row = down(five_row)
                five_col = left(five_col)
        five_positions.append([five_col, five_row])
        five_position = [five_col, five_row]
        
        
        if five_position in [[six_col+1,six_row],[six_col-1,six_row],[six_col,six_row+1], #if head is around tail or in the same spot as tail
                              [six_col, six_row-1],[six_col+1, six_row+1],[six_col+1,six_row-1],
                              [six_col-1, six_row+1],[six_col-1, six_row-1],[six_col,six_row]]:
            six_col = six_col
            six_row = six_row
        elif (five_col == six_col) and (five_row != six_row): #if head is in the same column but different row as tail
            if five_row > six_row: #head is 2 spots up from tail
                six_row = up(six_row)
            else: #head is 2 spots down from tail
                six_row = down(six_row)
        elif (five_col != six_col) and (five_row == six_row): #if head is in the same row but different col as tail
            if five_col > six_col: #head is 2 spots to the right from tail
                six_col = right(six_col)
            else: #head is 2 spots to the left from tail
                six_col = left(six_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (five_col > six_col) and (five_row > six_row): #tail needs to move right & up
                six_row = up(six_row)
                six_col = right(six_col)
            elif (five_col > six_col) and (five_row < six_row): #tail needs to move right & down
                six_row = down(six_row)
                six_col = right(six_col)
            elif (five_col < six_col) and (five_row > six_row): #tail needs to move left & up
                six_row = up(six_row)
                six_col = left(six_col)
            else: #tail needs to move left & down
                six_row = down(six_row)
                six_col = left(six_col)
        six_positions.append([six_col, six_row])
        six_position = [six_col, six_row]
        
             
        if six_position in [[seven_col+1,seven_row],[seven_col-1,seven_row],[seven_col,seven_row+1], #if head is around tail or in the same spot as tail
                              [seven_col, seven_row-1],[seven_col+1, seven_row+1],[seven_col+1,seven_row-1],
                              [seven_col-1, seven_row+1],[seven_col-1, seven_row-1],[seven_col,seven_row]]:
            seven_col = seven_col
            seven_row = seven_row
        elif (six_col == seven_col) and (six_row != seven_row): #if head is in the same column but different row as tail
            if six_row > seven_row: #head is 2 spots up from tail
                seven_row = up(seven_row)
            else: #head is 2 spots down from tail
                seven_row = down(seven_row)
        elif (six_col != seven_col) and (six_row == seven_row): #if head is in the same row but different col as tail
            if six_col > seven_col: #head is 2 spots to the right from tail
                seven_col = right(seven_col)
            else: #head is 2 spots to the left from tail
                seven_col = left(seven_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (six_col > seven_col) and (six_row > seven_row): #tail needs to move right & up
                seven_row = up(seven_row)
                seven_col = right(seven_col)
            elif (six_col > seven_col) and (six_row < seven_row): #tail needs to move right & down
                seven_row = down(seven_row)
                seven_col = right(seven_col)
            elif (six_col < seven_col) and (six_row > seven_row): #tail needs to move left & up
                seven_row = up(seven_row)
                seven_col = left(seven_col)
            else: #tail needs to move left & down
                seven_row = down(seven_row)
                seven_col = left(seven_col)
        seven_positions.append([seven_col, seven_row])
        seven_position = [seven_col, seven_row]
        
        
        if seven_position in [[eight_col+1,eight_row],[eight_col-1,eight_row],[eight_col,eight_row+1], #if head is around tail or in the same spot as tail
                              [eight_col, eight_row-1],[eight_col+1, eight_row+1],[eight_col+1,eight_row-1],
                              [eight_col-1, eight_row+1],[eight_col-1, eight_row-1],[eight_col,eight_row]]:
            eight_col = eight_col
            eight_row = eight_row
        elif (seven_col == eight_col) and (seven_row != eight_row): #if head is in the same column but different row as tail
            if seven_row > eight_row: #head is 2 spots up from tail
                eight_row = up(eight_row)
            else: #head is 2 spots down from tail
                eight_row = down(eight_row)
        elif (seven_col != eight_col) and (seven_row == eight_row): #if head is in the same row but different col as tail
            if seven_col > eight_col: #head is 2 spots to the right from tail
                eight_col = right(eight_col)
            else: #head is 2 spots to the left from tail
                eight_col = left(eight_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (seven_col > eight_col) and (seven_row > eight_row): #tail needs to move right & up
                eight_row = up(eight_row)
                eight_col = right(eight_col)
            elif (seven_col > eight_col) and (seven_row < eight_row): #tail needs to move right & down
                eight_row = down(eight_row)
                eight_col = right(eight_col)
            elif (seven_col < eight_col) and (seven_row > eight_row): #tail needs to move left & up
                eight_row = up(eight_row)
                eight_col = left(eight_col)
            else: #tail needs to move left & down
                eight_row = down(eight_row)
                eight_col = left(eight_col)
        eight_positions.append([eight_col, eight_row])
        eight_position = [eight_col, eight_row]
        
        
        if seven_position in [[eight_col+1,eight_row],[eight_col-1,eight_row],[eight_col,eight_row+1], #if head is around tail or in the same spot as tail
                              [eight_col, eight_row-1],[eight_col+1, eight_row+1],[eight_col+1,eight_row-1],
                              [eight_col-1, eight_row+1],[eight_col-1, eight_row-1],[eight_col,eight_row]]:
            eight_col = eight_col
            eight_row = eight_row
        elif (seven_col == eight_col) and (seven_row != eight_row): #if head is in the same column but different row as tail
            if seven_row > eight_row: #head is 2 spots up from tail
                eight_row = up(eight_row)
            else: #head is 2 spots down from tail
                eight_row = down(eight_row)
        elif (seven_col != eight_col) and (seven_row == eight_row): #if head is in the same row but different col as tail
            if seven_col > eight_col: #head is 2 spots to the right from tail
                eight_col = right(eight_col)
            else: #head is 2 spots to the left from tail
                eight_col = left(eight_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (seven_col > eight_col) and (seven_row > eight_row): #tail needs to move right & up
                eight_row = up(eight_row)
                eight_col = right(eight_col)
            elif (seven_col > eight_col) and (seven_row < eight_row): #tail needs to move right & down
                eight_row = down(eight_row)
                eight_col = right(eight_col)
            elif (seven_col < eight_col) and (seven_row > eight_row): #tail needs to move left & up
                eight_row = up(eight_row)
                eight_col = left(eight_col)
            else: #tail needs to move left & down
                eight_row = down(eight_row)
                eight_col = left(eight_col)
        eight_positions.append([eight_col, eight_row])
        eight_position = [eight_col, eight_row]
        
        if eight_position in [[nine_col+1,nine_row],[nine_col-1,nine_row],[nine_col,nine_row+1], #if head is around tail or in the same spot as tail
                              [nine_col, nine_row-1],[nine_col+1, nine_row+1],[nine_col+1,nine_row-1],
                              [nine_col-1, nine_row+1],[nine_col-1, nine_row-1],[nine_col,nine_row]]:
            nine_col = nine_col
            nine_row = nine_row
        elif (eight_col == nine_col) and (eight_row != nine_row): #if head is in the same column but different row as tail
            if eight_row > nine_row: #head is 2 spots up from tail
                nine_row = up(nine_row)
            else: #head is 2 spots down from tail
                nine_row = down(nine_row)
        elif (eight_col != nine_col) and (eight_row == nine_row): #if head is in the same row but different col as tail
            if eight_col > nine_col: #head is 2 spots to the right from tail
                nine_col = right(nine_col)
            else: #head is 2 spots to the left from tail
                nine_col = left(nine_col)
        else: #head and tail are in different h_rows and h_cols (tail needs to move diagonally)
            if (eight_col > nine_col) and (eight_row > nine_row): #tail needs to move right & up
                nine_row = up(nine_row)
                nine_col = right(nine_col)
            elif (eight_col > nine_col) and (eight_row < nine_row): #tail needs to move right & down
                nine_row = down(nine_row)
                nine_col = right(nine_col)
            elif (eight_col < nine_col) and (eight_row > nine_row): #tail needs to move left & up
                nine_row = up(nine_row)
                nine_col = left(nine_col)
            else: #tail needs to move left & down
                nine_row = down(nine_row)
                nine_col = left(nine_col)
        nine_positions.append([nine_col, nine_row])
        nine_position = [nine_col, nine_row]
        

nine_unique_positions = []

for sublist in nine_positions:
    if sublist not in nine_unique_positions:
        nine_unique_positions.append(sublist)

print(len(nine_unique_positions))
# Out:
# 2602
